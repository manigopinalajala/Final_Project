# %% [markdown]
# <a href="https://colab.research.google.com/github/manigopinalajala/Final_Project/blob/master/final_half_with_gcn_GOPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow_recommenders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_recommenders
#   Downloading tensorflow_recommenders-0.7.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow_recommenders) (2.12.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow_recommenders) (1.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.20.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.12.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.32.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.22.4)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (23.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (67.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (23.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.2.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (16.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (4.5.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.4.8)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (3.3.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (2.12.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow>=2.9.0->tensorflow_recommenders) (1.53.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow>=2.9.0->tensorflow_recommenders) (0.40.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow>=2.9.0->tensorflow_recommenders) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow>=2.9.0->tensorflow_recommenders) (0.0.4)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (2.2.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (2.17.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (2.27.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (6.3.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=2.9.0->tensorflow_recommenders) (3.2.2)
# Installing collected packages: tensorflow_recommenders
# Successfully installed tensorflow_recommenders-0.7.3

# %%
pip install tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 15.0 MB/s eta 0:00:00
# Collecting typeguard<3.0.0,>=2.7
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow-addons) (23.0)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (BatchNormalization, Conv2D, UpSampling2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, MaxPooling2D)
import os
import cv2
from tensorflow.keras.optimizers import Adam
from keras.layers import DepthwiseConv2D
from keras.layers import Input
from keras.losses import CategoricalCrossentropy
import shutil
from PIL import Image
import numpy as np
from keras.layers import DepthwiseConv2D
from keras.layers import Input, Conv2D, UpSampling2D, MaxPooling2D, MaxPooling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from matplotlib import pyplot as plt
import glob
from scipy.io import loadmat
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Conv2D, MaxPooling2D,Conv1D
#from tensorflow_addons import SpatialPyramidPooling2D
from keras import backend as K
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import UpSampling2D
from tensorflow.keras.layers import SeparableConv2D
#from tensorflow.keras.layers import SpatialPyramidPooling2D
from tensorflow.keras.layers import BatchNormalization,GlobalAveragePooling2D,MaxPooling2D,AveragePooling2D
from tensorflow.keras import activations
#import tensorflow_recommenders as tfrs
import tensorflow_addons as tfa
from keras.utils import np_utils
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, LearningRateScheduler
import tensorflow_recommenders as tfr
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image as im
train_images = []
count=0
path = "/content/drive/MyDrive/glucomadata/train/tr_images/"
for file in  sorted(os.listdir(path)):
        img = cv2.imread("/content/drive/MyDrive/glucomadata/train/tr_images/"+file, cv2.IMREAD_COLOR) 
        
        if img is None:
          pass
        else:
          img = cv2.resize(img, (512,512),interpolation = cv2.INTER_AREA)
          img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        #img = img/255.
          train_images.append(img)
        count=count+1
        if (count==300):
          break

# %%
print(np.asarray(train_images).shape)
train_images2=train_images[:200]
train_images1=np.array(train_images2)
print(train_images1.shape)
print(type(train_images1))
#print(img1.shape)
# Out:
# (299, 512, 512, 3)
# (200, 512, 512, 3)
# <class 'numpy.ndarray'>

# %%
plt.imshow(train_images1[2])

# %%
image_path="/content/drive/MyDrive/glucomadata/train/tr_masks/"
images = [img for img in sorted(os.listdir(image_path)) if img.endswith(".png")]

# %%
img = np.array(Image.open("/content/drive/MyDrive/glucomadata/train/tr_masks/001.png"))
img = cv2.resize(img, (512,512),interpolation = cv2.INTER_AREA)
img.shape
np.unique(img)
# Out:
# array([0, 1, 2], dtype=uint8)

# %%
k= keras.utils.to_categorical(img, num_classes=3)[:,:,1:]

# %%
import numpy as np
import cv2
import os
from PIL import Image as im
train_masks = []
path = "/content/drive/MyDrive/glucomadata/train/tr_masks/"
for file in  images:
        img = np.array(Image.open("/content/drive/MyDrive/glucomadata/train/tr_masks/"+file))
        
        img = cv2.resize(img, (512,512),interpolation = cv2.INTER_AREA)

        # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        #img = img/255.
        train_masks.append(img)

# %%
np.shape(train_masks)
# Out:
# (450, 512, 512)

# %%
train_masks2=train_masks[:200]
train_masks1=np.array(train_masks2)
print(train_masks1.shape)
print(type(train_masks1))
#print(img1.shape)
# Out:
# (200, 512, 512)
# <class 'numpy.ndarray'>

# %%
plt.imshow(train_masks1[5])

# %%
"""

import cv2
import glob

def clahe_preprocessing(image, clip_limit=2.0, grid_size=(8,8)):
    
    # Convert image to LAB color space
    if image is None:
      pass
    else:

      lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

      # Split channels
      l, a, b = cv2.split(lab)

      # Apply CLAHE to the L channel
      clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=grid_size)
      l_clahe = clahe.apply(l)

      # Merge channels and convert back to RGB color space
      lab_clahe = cv2.merge((l_clahe, a, b))
      output = cv2.cvtColor(lab_clahe, cv2.COLOR_LAB2BGR)

      return output


# Load images
# images = glob.glob('/content/drive/MyDrive/glucomadata/train/tr_images/*.jpg')[:400] # Limit to 400 images for example purposes

# Preprocess images, resize to (512, 512), and save in list
preprocessed_images = []
path = "/content/drive/MyDrive/glucomadata/train/tr_images/"
for image in  sorted(os.listdir(path)):
    # Load image
    image = cv2.imread("/content/drive/MyDrive/glucomadata/train/tr_images/"+image, cv2.IMREAD_COLOR)

    # Preprocess image using CLAHE
    preprocessed_image = clahe_preprocessing(image)

    # Resize image to (512, 512)
    if image is None:
      pass
    else:

      preprocessed_image = cv2.resize(preprocessed_image, (512, 512))
      preprocessed_image = cv2.cvtColor(preprocessed_image, cv2.COLOR_BGR2RGB)
      # Append preprocessed image to list
      preprocessed_images.append(preprocessed_image)
"""
# Out:
# '\n\nimport cv2\nimport glob\n\ndef clahe_preprocessing(image, clip_limit=2.0, grid_size=(8,8)):\n    \n    # Convert image to LAB color space\n    if image is None:\n      pass\n    else:\n\n      lab = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)\n\n      # Split channels\n      l, a, b = cv2.split(lab)\n\n      # Apply CLAHE to the L channel\n      clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=grid_size)\n      l_clahe = clahe.apply(l)\n\n      # Merge channels and convert back to RGB color space\n      lab_clahe = cv2.merge((l_clahe, a, b))\n      output = cv2.cvtColor(lab_clahe, cv2.COLOR_LAB2BGR)\n\n      return output\n\n\n# Load images\n# images = glob.glob(\'/content/drive/MyDrive/glucomadata/train/tr_images/*.jpg\')[:400] # Limit to 400 images for example purposes\n\n# Preprocess images, resize to (512, 512), and save in list\npreprocessed_images = []\npath = "/content/drive/MyDrive/glucomadata/train/tr_images/"\nfor image in  sorted(os.listdir(path)):\n    # Load image\n    image = cv2.imread("/content/drive/MyDrive/glucomadata/train/tr_images/"+image, cv2.IMREAD_COLOR)\n\n    # Preprocess image using CLAHE\n    preprocessed_image = clahe_preprocessing(image)\n\n    # Resize image to (512, 512)\n    if image is None:\n      pass\n    else:\n\n      preprocessed_image = cv2.resize(preprocessed_image, (512, 512))\n      preprocessed_image = cv2.cvtColor(preprocessed_image, cv2.COLOR_BGR2RGB)\n      # Append preprocessed image to list\n      preprocessed_images.append(preprocessed_image)\n'

# %%
np.shape(train_masks1)

# k= to_categorical(train_masks1[1], num_classes=2)[:,:,1:]
# Out:
# (200, 512, 512)

# %%
from tensorflow.keras.utils import to_categorical
y_train_final=[]
n_classes=3
for y_train1 in (train_masks1):
  y_train1
  y_train_final.append(to_categorical(y_train1, num_classes=n_classes)[:,:,1:])
# print(train_masks_cat.shape)
# y_train_cat = train_masks_cat.reshape((y_train.shape[0],y_train.shape[2], n_classes))
y_train_1= np.array(y_train_final)

# %%
IMG_HEIGHT = 512
IMG_WIDTH = 512
IMG_CHANNELS=3

# %%
def dgcn(tensor):

  #Graph convolution in Coordinate space
  #Coordinate space projection
  
  v=AveragePooling2D(pool_size = 2, strides = 2)(tensor)
  v=DepthwiseConv2D(kernel_size=(3,3),strides=(2,2))(v)
  
  v=DepthwiseConv2D(kernel_size=(3,3),strides=(2,2))(v)
  
  v=DepthwiseConv2D(kernel_size=(3,3),strides=(2,2))(v)
 
  v=DepthwiseConv2D(kernel_size=(3,3),strides=(2,2))(v)
 
  v=DepthwiseConv2D(kernel_size=(3,3),strides=(2,2))(v)
  
  v=DepthwiseConv2D(kernel_size=(3,3),strides=(2,2))(v)
  
  v=DepthwiseConv2D(kernel_size=(3,3),strides=(2,2))(v)
 
  

  #coordinate space GCN
  vs=v
  delta=Conv2D(128,kernel_size=(1,1))(vs)
  
  psi=Conv2D(128,kernel_size=(1,1))(vs)
  
  #psi=tf.transpose(psi,perm=[0,3,2,1])
  
  upsilon=Conv2D(128,kernel_size=(1,1))(vs)
  
  AS=dot_product(psi,upsilon)
  
  #AS=tf.transpose(AS,perm=[0,3,2,1])
 
  AVS=dot_product(delta,AS) 
  
  #AVS=tf.expand_dims(AVS, axis=-1)
  
  upsample=tf.keras.layers.UpSampling2D(size=512, interpolation='nearest')(AVS)
  
  out1=Conv2D(128,kernel_size=(1,1))(upsample)


  #Graph Convolution In Feature Space
  #Feature Space projection
  #D=channels
  #D1=D/2
  #D2=D/4
  D=64
  D1=32
  D2=16
  theta=Conv2D(128,kernel_size=(1,1))(tensor)
  theta=tf.keras.layers.BatchNormalization()(theta)
  theta=tf.keras.layers.Activation('relu')(theta)
  hft=theta
  #hft=tf.transpose(theta)
  psi=Conv2D(128,kernel_size=(1,1))(tensor)
  psi=tf.keras.layers.BatchNormalization()(psi)
  psi=tf.keras.layers.Activation('relu')(psi)
  vf=dot_product(hft,psi)
  
  #vf=tf.transpose(vf)
  af=Conv1D(128,kernel_size=1)(vf)
  
  af=tf.keras.layers.BatchNormalization()(af)
  
  af=tf.keras.layers.Activation('relu')(af)
  
  w=vf+af
 
  wf=Conv1D(128,1)(w)

  wf=tf.keras.layers.BatchNormalization()(wf)
 

  wf=tf.keras.layers.Activation('relu')(wf)
 

  #wf=tf.transpose(wf)
  h=dot_product(theta,wf)
  
  #h=tf.expand_dims(h, axis=-1)
  out3=Conv2D(128,kernel_size=(1,1))(h)
  
  out3=tf.keras.layers.BatchNormalization()(out3)
  
  out3=tf.keras.layers.Activation('relu')(out3)
  
  res=out1+tensor+out3
  

  
  
  return res


def dot_product(tensor1,tensor2):
  # perform element-wise multiplication
  elementwise_mult = tf.multiply(tensor1, tensor2)

  # sum along the appropriate axis
  #dot_prod = tf.reduce_sum(elementwise_mult, axis=-1)
  return elementwise_mult

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, concatenate, Conv2DTranspose

def conv_block(inputs, filters, kernel_size=3, activation='relu'):
    x = Conv2D(filters=filters, kernel_size=kernel_size, padding='same', activation=activation)(inputs)
    x = Conv2D(filters=filters, kernel_size=kernel_size, padding='same', activation=activation)(x)
    return x

def UNet(input_shape):
    # Define input layer
    # inputs = Input(shape=input_shape)
    
    # Downsample path
    conv1 = conv_block(input_shape, 64)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = conv_block(pool1, 128)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = conv_block(pool2, 256)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = conv_block(pool3, 512)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    
    # Bottom
    conv5 = conv_block(pool4, 1024)
    
    # Upsample path
    up6 = Conv2DTranspose(filters=512, kernel_size=2, strides=(2, 2), padding='same')(conv5)
    up6 = concatenate([up6, conv4])
    conv6 = conv_block(up6, 512)
    
    up7 = Conv2DTranspose(filters=256, kernel_size=2, strides=(2, 2), padding='same')(conv6)
    up7 = concatenate([up7, conv3])
    conv7 = conv_block(up7, 256)
    
    up8 = Conv2DTranspose(filters=128, kernel_size=2, strides=(2, 2), padding='same')(conv7)
    up8 = concatenate([up8, conv2])
    conv8 = conv_block(up8, 128)
    
    up9 = Conv2DTranspose(filters=64, kernel_size=2, strides=(2, 2), padding='same')(conv8)
    up9 = concatenate([up9, conv1])
    conv9 = conv_block(up9, 64)
    
    # Output layer
    outputs = Conv2D(filters=1, kernel_size=1, activation='sigmoid')(conv9)
    
    # Create model
    # model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return outputs

# %%
from keras.layers.normalization import batch_normalization
from keras.layers import DepthwiseConv2D
def deepconvnet1(input_size):
  IMG_HEIGHT1=int(IMG_HEIGHT/2)
  IMG_WIDTH1=int(IMG_WIDTH/2)
  
  #inputs =input_size/4
  #inputs=tf.convert_to_tensor(inputs, dtype=None, dtype_hint=None, name=None)
  #print("Input Shape",inputs.shape)
  #print("Input dtype",inputs)
  inputs=Input((IMG_HEIGHT,IMG_WIDTH,3))
  c0=Conv2D(1,(3,3),strides=(1,1),activation = 'relu',padding='same')(inputs)
  
  c1=Conv2D(2,(3,3),strides=(1,1),activation = 'relu',padding='same')(c0)
  lowlevelimage=Conv2D(32,kernel_size=(1,1),strides =(1,1))(c1)
 


  c2=Conv2D(4,(1,1),strides=(1,1),activation = 'relu',padding='same')(c1)
  
  c3=SeparableConv2D(4,(3,3),strides=(1,1),activation = 'relu',padding='same')(c1)
  c4=SeparableConv2D(4,(3,3),strides=(1,1),activation = 'relu',padding='same')(c3)
  c5=tf.add(c2,c4)
  print("c2",c2)
  print("c4",c4)
  print("c5",c5)
  c6=Conv2D(8,(1,1),strides=(1,1),activation = 'relu',padding='same')(c5)
  c7=SeparableConv2D(8,(3,3),strides=(1,1),activation = 'relu',padding='same')(c5)
  c8=SeparableConv2D(8,(3,3),strides=(1,1),activation = 'relu',padding='same')(c7)
  c9=tf.add(c6,c8)
  print("c6",c6)
  print("c7",c7)
  print("c9",c9)

  c10=Conv2D(16,(1,1),strides=(1,1),activation = 'relu',padding='same')(c9)
  c11=SeparableConv2D(16,(3,3),strides=(1,1),activation = 'relu',padding='same')(c9)
  c12=SeparableConv2D(16,(3,3),strides=(1,1),activation = 'relu',padding='same')(c11)
  c13=tf.add(c10,c12)

  c14=Conv2D(32,(1,1),strides=(1,1),activation = 'relu',padding='same')(c13)
  c15=SeparableConv2D(32,(3,3),strides=(1,1),activation = 'relu',padding='same')(c13)
  c16=SeparableConv2D(32,(3,3),strides=(1,1),activation = 'relu',padding='same')(c15)
  c17=tf.add(c14,c16)

  c18=SeparableConv2D(64,(3,3),strides=(1,1),activation = 'relu',padding='same')(c17)
  c19=SeparableConv2D(64,(3,3),strides=(1,1),activation = 'relu',padding='same')(c18) 
  c20=SeparableConv2D(64,(3,3),strides=(1,1),activation = 'relu',padding='same')(c19)
  
  ASPP640=aspp(c20)

  c21=Conv2D(128,(1,1),activation = 'relu',padding='same')(ASPP640)
  upsample=UpSampling2D(size=(1,1))(c21)
  c22=concatenate([upsample,c7])
  c23=SeparableConv2D(128,(1,1),activation = 'relu',padding='same')(c22)
 
  highlevelimage=SeparableConv2D(128,(3,3),activation = 'relu',padding='same')(c23)
  

  output=Conv2D(2,(1,1),activation='sigmoid',padding='same')(highlevelimage)
  inputs1=Input((IMG_HEIGHT,IMG_WIDTH,3))
  res=dgcn(highlevelimage)
 
  res=Conv2D(2,(1,1),strides=(1,1),activation='relu',padding='same')(res)
 
  res=tf.keras.layers.UpSampling2D(size=1, interpolation='nearest')(res)
  
  # res= MaxPooling2D(pool_size=(2, 2))(res) 
  output=UNet(res)
  
  out=Conv2D(2,(1,1),strides=(1,1),activation='relu',padding='same')(output)
  model=Model(inputs=inputs,outputs=out)

  return model
  
def aspp(inp):
  
  print(inp.shape)
  m1=Conv2D(64,(1,1),dilation_rate=(1, 1),padding='same')(inp)
  print(m1.shape)
  m2=BatchNormalization()(m1)

  m3=Conv2D(64,(3,3),dilation_rate=(2,2),activation='relu',padding='same')(inp)
  m4=BatchNormalization()(m3)

  m5=Conv2D(64,(3,3),dilation_rate=(4, 4),activation='relu',padding='same')(inp)
  m6=BatchNormalization()(m3)

  m7=Conv2D(64,(3,3),dilation_rate=(6, 6),activation='relu',padding='same')(inp)
  m8=BatchNormalization()(m7)




  m9=AveragePooling2D(pool_size=(2, 2), strides=None, padding="valid", data_format=None)(inp)
  m10=Conv2D(64,(1,1),padding='same')(m9)
  m11=BatchNormalization()(m10)
  m12=UpSampling2D(interpolation='bilinear')(m11)
  m13=concatenate([m2,m4])
  m14=concatenate([m13,m6])
  m15=concatenate([m14,m8])
  m16=concatenate([m15,m12])

  m17=Conv2D(128,(1,1),padding='same')(m16)
  mm18=BatchNormalization()(m17)
  print(m17.shape)
  return m17

# %%
IMG_HEIGHT=512
IMG_WIDTH=512
model=deepconvnet1((512,512,3))
# Out:
# c2 KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 4), dtype=tf.float32, name=None), name='conv2d_46/Relu:0', description="created by layer 'conv2d_46'")
# c4 KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 4), dtype=tf.float32, name=None), name='separable_conv2d_14/Relu:0', description="created by layer 'separable_conv2d_14'")
# c5 KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 4), dtype=tf.float32, name=None), name='tf.math.add_4/Add:0', description="created by layer 'tf.math.add_4'")
# c6 KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 8), dtype=tf.float32, name=None), name='conv2d_47/Relu:0', description="created by layer 'conv2d_47'")
# c7 KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 8), dtype=tf.float32, name=None), name='separable_conv2d_15/Relu:0', description="created by layer 'separable_conv2d_15'")
# c9 KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 8), dtype=tf.float32, name=None), name='tf.math.add_5/Add:0', description="created by layer 'tf.math.add_5'")
# (None, 512, 512, 64)
# (None, 512, 512, 64)
# (None, 512, 512, 128)

# %% [markdown]
# # Training

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_43 (Conv2D)             (None, 512, 512, 1)  28          ['input_3[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 512, 512, 2)  20          ['conv2d_43[0][0]']
#
#  separable_conv2d_13 (Separable  (None, 512, 512, 4)  30         ['conv2d_44[0][0]']
#  Conv2D)
#
#  conv2d_46 (Conv2D)             (None, 512, 512, 4)  12          ['conv2d_44[0][0]']
#
#  separable_conv2d_14 (Separable  (None, 512, 512, 4)  56         ['separable_conv2d_13[0][0]']
#  Conv2D)
#
#  tf.math.add_4 (TFOpLambda)     (None, 512, 512, 4)  0           ['conv2d_46[0][0]',
#                                                                   'separable_conv2d_14[0][0]']
#
#  separable_conv2d_15 (Separable  (None, 512, 512, 8)  76         ['tf.math.add_4[0][0]']
#  Conv2D)
#
#  conv2d_47 (Conv2D)             (None, 512, 512, 8)  40          ['tf.math.add_4[0][0]']
#
#  separable_conv2d_16 (Separable  (None, 512, 512, 8)  144        ['separable_conv2d_15[0][0]']
#  Conv2D)
#
#  tf.math.add_5 (TFOpLambda)     (None, 512, 512, 8)  0           ['conv2d_47[0][0]',
#                                                                   'separable_conv2d_16[0][0]']
#
#  separable_conv2d_17 (Separable  (None, 512, 512, 16  216        ['tf.math.add_5[0][0]']
#  Conv2D)                        )
#
#  conv2d_48 (Conv2D)             (None, 512, 512, 16  144         ['tf.math.add_5[0][0]']
#                                 )
#
#  separable_conv2d_18 (Separable  (None, 512, 512, 16  416        ['separable_conv2d_17[0][0]']
#  Conv2D)                        )
#
#  tf.math.add_6 (TFOpLambda)     (None, 512, 512, 16  0           ['conv2d_48[0][0]',
#                                 )                                 'separable_conv2d_18[0][0]']
#
#  separable_conv2d_19 (Separable  (None, 512, 512, 32  688        ['tf.math.add_6[0][0]']
#  Conv2D)                        )
#
#  conv2d_49 (Conv2D)             (None, 512, 512, 32  544         ['tf.math.add_6[0][0]']
#                                 )
#
#  separable_conv2d_20 (Separable  (None, 512, 512, 32  1344       ['separable_conv2d_19[0][0]']
#  Conv2D)                        )
#
#  tf.math.add_7 (TFOpLambda)     (None, 512, 512, 32  0           ['conv2d_49[0][0]',
#                                 )                                 'separable_conv2d_20[0][0]']
#
#  separable_conv2d_21 (Separable  (None, 512, 512, 64  2400       ['tf.math.add_7[0][0]']
#  Conv2D)                        )
#
#  separable_conv2d_22 (Separable  (None, 512, 512, 64  4736       ['separable_conv2d_21[0][0]']
#  Conv2D)                        )
#
#  separable_conv2d_23 (Separable  (None, 512, 512, 64  4736       ['separable_conv2d_22[0][0]']
#  Conv2D)                        )
#
#  conv2d_50 (Conv2D)             (None, 512, 512, 64  4160        ['separable_conv2d_23[0][0]']
#                                 )
#
#  conv2d_51 (Conv2D)             (None, 512, 512, 64  36928       ['separable_conv2d_23[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 512, 512, 64  256        ['conv2d_50[0][0]']
#  ormalization)                  )
#
#  batch_normalization_12 (BatchN  (None, 512, 512, 64  256        ['conv2d_51[0][0]']
#  ormalization)                  )
#
#  average_pooling2d_2 (AveragePo  (None, 256, 256, 64  0          ['separable_conv2d_23[0][0]']
#  oling2D)                       )
#
#  concatenate_9 (Concatenate)    (None, 512, 512, 12  0           ['batch_normalization_11[0][0]',
#                                 8)                                'batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 512, 512, 64  256        ['conv2d_51[0][0]']
#  ormalization)                  )
#
#  conv2d_53 (Conv2D)             (None, 512, 512, 64  36928       ['separable_conv2d_23[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 256, 256, 64  4160        ['average_pooling2d_2[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 512, 512, 19  0           ['concatenate_9[0][0]',
#                                 2)                                'batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 512, 512, 64  256        ['conv2d_53[0][0]']
#  ormalization)                  )
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 64  256        ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  concatenate_11 (Concatenate)   (None, 512, 512, 25  0           ['concatenate_10[0][0]',
#                                 6)                                'batch_normalization_14[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 512, 512, 64  0          ['batch_normalization_15[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 512, 512, 32  0           ['concatenate_11[0][0]',
#                                 0)                                'up_sampling2d_4[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 512, 512, 12  41088       ['concatenate_12[0][0]']
#                                 8)
#
#  conv2d_56 (Conv2D)             (None, 512, 512, 12  16512       ['conv2d_55[0][0]']
#                                 8)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 512, 512, 12  0          ['conv2d_56[0][0]']
#                                 8)
#
#  concatenate_13 (Concatenate)   (None, 512, 512, 13  0           ['up_sampling2d_5[0][0]',
#                                 6)                                'separable_conv2d_15[0][0]']
#
#  separable_conv2d_24 (Separable  (None, 512, 512, 12  17672      ['concatenate_13[0][0]']
#  Conv2D)                        8)
#
#  separable_conv2d_25 (Separable  (None, 512, 512, 12  17664      ['separable_conv2d_24[0][0]']
#  Conv2D)                        8)
#
#  conv2d_62 (Conv2D)             (None, 512, 512, 12  16512       ['separable_conv2d_25[0][0]']
#                                 8)
#
#  conv2d_63 (Conv2D)             (None, 512, 512, 12  16512       ['separable_conv2d_25[0][0]']
#                                 8)
#
#  average_pooling2d_3 (AveragePo  (None, 256, 256, 12  0          ['separable_conv2d_25[0][0]']
#  oling2D)                       8)
#
#  batch_normalization_17 (BatchN  (None, 512, 512, 12  512        ['conv2d_62[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_18 (BatchN  (None, 512, 512, 12  512        ['conv2d_63[0][0]']
#  ormalization)                  8)
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 127, 127, 12  1280       ['average_pooling2d_3[0][0]']
#  onv2D)                         8)
#
#  activation_5 (Activation)      (None, 512, 512, 12  0           ['batch_normalization_17[0][0]']
#                                 8)
#
#  activation_6 (Activation)      (None, 512, 512, 12  0           ['batch_normalization_18[0][0]']
#                                 8)
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 63, 63, 128)  1280       ['depthwise_conv2d_7[0][0]']
#  onv2D)
#
#  tf.math.multiply_6 (TFOpLambda  (None, 512, 512, 12  0          ['activation_5[0][0]',
#  )                              8)                                'activation_6[0][0]']
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 31, 31, 128)  1280       ['depthwise_conv2d_8[0][0]']
#  onv2D)
#
#  conv1d_2 (Conv1D)              (None, 512, 512, 12  16512       ['tf.math.multiply_6[0][0]']
#                                 8)
#
#  depthwise_conv2d_10 (Depthwise  (None, 15, 15, 128)  1280       ['depthwise_conv2d_9[0][0]']
#  Conv2D)
#
#  batch_normalization_19 (BatchN  (None, 512, 512, 12  512        ['conv1d_2[0][0]']
#  ormalization)                  8)
#
#  depthwise_conv2d_11 (Depthwise  (None, 7, 7, 128)   1280        ['depthwise_conv2d_10[0][0]']
#  Conv2D)
#
#  activation_7 (Activation)      (None, 512, 512, 12  0           ['batch_normalization_19[0][0]']
#                                 8)
#
#  depthwise_conv2d_12 (Depthwise  (None, 3, 3, 128)   1280        ['depthwise_conv2d_11[0][0]']
#  Conv2D)
#
#  tf.__operators__.add_3 (TFOpLa  (None, 512, 512, 12  0          ['tf.math.multiply_6[0][0]',
#  mbda)                          8)                                'activation_7[0][0]']
#
#  depthwise_conv2d_13 (Depthwise  (None, 1, 1, 128)   1280        ['depthwise_conv2d_12[0][0]']
#  Conv2D)
#
#  conv1d_3 (Conv1D)              (None, 512, 512, 12  16512       ['tf.__operators__.add_3[0][0]']
#                                 8)
#
#  conv2d_59 (Conv2D)             (None, 1, 1, 128)    16512       ['depthwise_conv2d_13[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 1, 1, 128)    16512       ['depthwise_conv2d_13[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 512, 512, 12  512        ['conv1d_3[0][0]']
#  ormalization)                  8)
#
#  conv2d_58 (Conv2D)             (None, 1, 1, 128)    16512       ['depthwise_conv2d_13[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 1, 1, 128)   0           ['conv2d_59[0][0]',
#  )                                                                'conv2d_60[0][0]']
#
#  activation_8 (Activation)      (None, 512, 512, 12  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  tf.math.multiply_5 (TFOpLambda  (None, 1, 1, 128)   0           ['conv2d_58[0][0]',
#  )                                                                'tf.math.multiply_4[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 512, 512, 12  0          ['activation_5[0][0]',
#  )                              8)                                'activation_8[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 512, 512, 12  0          ['tf.math.multiply_5[0][0]']
#                                 8)
#
#  conv2d_64 (Conv2D)             (None, 512, 512, 12  16512       ['tf.math.multiply_7[0][0]']
#                                 8)
#
#  conv2d_61 (Conv2D)             (None, 512, 512, 12  16512       ['up_sampling2d_6[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 512, 512, 12  512        ['conv2d_64[0][0]']
#  ormalization)                  8)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 512, 512, 12  0          ['conv2d_61[0][0]',
#  mbda)                          8)                                'separable_conv2d_25[0][0]']
#
#  activation_9 (Activation)      (None, 512, 512, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  tf.__operators__.add_5 (TFOpLa  (None, 512, 512, 12  0          ['tf.__operators__.add_4[0][0]',
#  mbda)                          8)                                'activation_9[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 512, 512, 2)  258         ['tf.__operators__.add_5[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 512, 512, 2)  0          ['conv2d_65[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 512, 512, 64  1216        ['up_sampling2d_7[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 512, 512, 64  36928       ['conv2d_66[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 256, 256, 64  0          ['conv2d_67[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 256, 256, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  conv2d_69 (Conv2D)             (None, 256, 256, 12  147584      ['conv2d_68[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 12  0          ['conv2d_69[0][0]']
#                                 8)
#
#  conv2d_70 (Conv2D)             (None, 128, 128, 25  295168      ['max_pooling2d_5[0][0]']
#                                 6)
#
#  conv2d_71 (Conv2D)             (None, 128, 128, 25  590080      ['conv2d_70[0][0]']
#                                 6)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 256)  0          ['conv2d_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 64, 64, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 64, 64, 512)  2359808     ['conv2d_72[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 512)  0          ['conv2d_73[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 32, 32, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  conv2d_75 (Conv2D)             (None, 32, 32, 1024  9438208     ['conv2d_74[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 512)  2097664    ['conv2d_75[0][0]']
#  spose)
#
#  concatenate_14 (Concatenate)   (None, 64, 64, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'conv2d_73[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_14[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 64, 64, 512)  2359808     ['conv2d_76[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 25  524544     ['conv2d_77[0][0]']
#  spose)                         6)
#
#  concatenate_15 (Concatenate)   (None, 128, 128, 51  0           ['conv2d_transpose_5[0][0]',
#                                 2)                                'conv2d_71[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_15[0][0]']
#                                 6)
#
#  conv2d_79 (Conv2D)             (None, 128, 128, 25  590080      ['conv2d_78[0][0]']
#                                 6)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 12  131200     ['conv2d_79[0][0]']
#  spose)                         8)
#
#  concatenate_16 (Concatenate)   (None, 256, 256, 25  0           ['conv2d_transpose_6[0][0]',
#                                 6)                                'conv2d_69[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_16[0][0]']
#                                 8)
#
#  conv2d_81 (Conv2D)             (None, 256, 256, 12  147584      ['conv2d_80[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 64  32832      ['conv2d_81[0][0]']
#  spose)                         )
#
#  concatenate_17 (Concatenate)   (None, 512, 512, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'conv2d_67[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_17[0][0]']
#                                 )
#
#  conv2d_83 (Conv2D)             (None, 512, 512, 64  36928       ['conv2d_82[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 512, 512, 1)  65          ['conv2d_83[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 512, 512, 2)  4           ['conv2d_84[0][0]']
#
# ==================================================================================================
# Total params: 31,383,581
# Trainable params: 31,381,661
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth=1e-7

def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision=(true_positives / (predicted_positives + K.epsilon()))
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
opt = Adam(learning_rate=0.0005 )
model.compile(optimizer='rmsprop',loss= 'binary_crossentropy', metrics = ['accuracy',iou,dice_coef,precision,f1_score])

# %%
np.asarray(train_images1).shape, np.asarray(y_train_final).shape
# Out:
# ((200, 512, 512, 3), (200, 512, 512, 2))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(train_images1,y_train_final,test_size=0.3)

# %%
print(np.asarray(x_train).shape)
print(np.asarray(x_test).shape)
print(np.asarray(y_train).shape)
print(np.asarray(y_test).shape)
# Out:
# (140, 512, 512, 3)
# (60, 512, 512, 3)
# (140, 512, 512, 2)
# (60, 512, 512, 2)

# %%
plt.imshow(x_train[1])
plt.show()
plt.imshow(y_train[1][:,:,0], cmap='gray')
plt.show()
plt.imshow(y_train[1][:,:,1], cmap='gray')
plt.show()

# %%
def get_callbacks(model_name):
    callbacks =[]
    tensor_board = tf.keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=0)
    callbacks.append(tensor_board)
    checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=f'model.{model_name}.h5', verbose=1, monitor='val_loss',mode='min',save_best_only=True)
    callbacks.append(checkpoint)
    anne = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, verbose=2, min_lr=0.0000001,min_delta=0.00001,mode='auto') 
    callbacks.append(anne)
    return callbacks

# %%
# (x_train[8])
# plt.imshow(x_train[8]/255.)
# # y_train[2].shape

# %%
x_train= np.array(x_train)
y_train=np.array(y_train)
y_test=np.array(y_test)
print(x_train.shape)
y_train.shape
y_test.shape
# Out:
# (140, 512, 512, 3)
# (60, 512, 512, 2)

# %%
#model = load_model('/content/drive/MyDrive/glucomadata/weights.h5')

# %%
callbacks = get_callbacks('model')
history=model.fit(x_train,y_train,batch_size=1,verbose=1,epochs=50,validation_data=(np.array(x_test),np.array(y_test)),shuffle=False,callbacks=[callbacks])
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1140 - accuracy: 0.2327 - iou: 0.0061 - dice_coef: 0.0121 - precision: 0.0000e+00 - f1_score: 0.0000e+00
# Epoch 1: val_loss improved from inf to 0.12030, saving model to model.model.h5
# 140/140 [==============================] - 135s 740ms/step - loss: 0.1140 - accuracy: 0.2327 - iou: 0.0061 - dice_coef: 0.0121 - precision: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.1203 - val_accuracy: 0.0066 - val_iou: 2.9747e-04 - val_dice_coef: 5.9474e-04 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 0.0010
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.7940 - iou: 0.0197 - dice_coef: 0.0384 - precision: 0.0000e+00 - f1_score: 0.0000e+00
# Epoch 2: val_loss did not improve from 0.12030
# 140/140 [==============================] - 101s 722ms/step - loss: 0.1094 - accuracy: 0.7940 - iou: 0.0197 - dice_coef: 0.0384 - precision: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.1467 - val_accuracy: 0.9780 - val_iou: 9.0990e-06 - val_dice_coef: 1.8196e-05 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 0.0010
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1062 - accuracy: 0.9051 - iou: 0.0451 - dice_coef: 0.0856 - precision: 0.0000e+00 - f1_score: 0.0000e+00
# Epoch 3: val_loss improved from 0.12030 to 0.10849, saving model to model.model.h5
# 140/140 [==============================] - 93s 662ms/step - loss: 0.1062 - accuracy: 0.9051 - iou: 0.0451 - dice_coef: 0.0856 - precision: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.1085 - val_accuracy: 0.9023 - val_iou: 0.0455 - val_dice_coef: 0.0862 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 0.0010
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1056 - accuracy: 0.8798 - iou: 0.0670 - dice_coef: 0.1242 - precision: 0.0000e+00 - f1_score: 0.0000e+00
# Epoch 4: val_loss did not improve from 0.10849
# 140/140 [==============================] - 91s 654ms/step - loss: 0.1056 - accuracy: 0.8798 - iou: 0.0670 - dice_coef: 0.1242 - precision: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.1456 - val_accuracy: 0.9780 - val_iou: 3.8070e-04 - val_dice_coef: 7.5596e-04 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 0.0010
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1043 - accuracy: 0.9284 - iou: 0.0876 - dice_coef: 0.1592 - precision: 0.0000e+00 - f1_score: 0.0000e+00
# Epoch 5: val_loss did not improve from 0.10849
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1043 - accuracy: 0.9284 - iou: 0.0876 - dice_coef: 0.1592 - precision: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.1469 - val_accuracy: 0.6666 - val_iou: 0.0360 - val_dice_coef: 0.0682 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 0.0010
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9407 - iou: 0.1041 - dice_coef: 0.1866 - precision: 0.0000e+00 - f1_score: 0.0000e+00
# Epoch 6: val_loss improved from 0.10849 to 0.10678, saving model to model.model.h5
# 140/140 [==============================] - 93s 661ms/step - loss: 0.1035 - accuracy: 0.9407 - iou: 0.1041 - dice_coef: 0.1866 - precision: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.1068 - val_accuracy: 0.8982 - val_iou: 0.0558 - val_dice_coef: 0.1027 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 5.0000e-04
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9061 - iou: 0.1132 - dice_coef: 0.2013 - precision: 0.0000e+00 - f1_score: 0.0000e+00
# Epoch 7: val_loss did not improve from 0.10678
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1033 - accuracy: 0.9061 - iou: 0.1132 - dice_coef: 0.2013 - precision: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.1333 - val_accuracy: 0.9761 - val_iou: 0.0152 - val_dice_coef: 0.0282 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 5.0000e-04
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9225 - iou: 0.1208 - dice_coef: 0.2131 - precision: 0.0000e+00 - f1_score: 0.0000e+00
# Epoch 8: val_loss did not improve from 0.10678
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 140/140 [==============================] - 91s 654ms/step - loss: 0.1032 - accuracy: 0.9225 - iou: 0.1208 - dice_coef: 0.2131 - precision: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.1242 - val_accuracy: 0.8306 - val_iou: 0.0762 - val_dice_coef: 0.1380 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 5.0000e-04
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1026 - accuracy: 0.9502 - iou: 0.1294 - dice_coef: 0.2266 - precision: 0.0000e+00 - f1_score: 0.0000e+00
# Epoch 9: val_loss did not improve from 0.10678
# 140/140 [==============================] - 101s 719ms/step - loss: 0.1026 - accuracy: 0.9502 - iou: 0.1294 - dice_coef: 0.2266 - precision: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.1182 - val_accuracy: 0.9766 - val_iou: 0.0684 - val_dice_coef: 0.1218 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 2.5000e-04
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9671 - iou: 0.1359 - dice_coef: 0.2364 - precision: 0.0000e+00 - f1_score: 0.0000e+00
# Epoch 10: val_loss did not improve from 0.10678
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 140/140 [==============================] - 92s 654ms/step - loss: 0.1024 - accuracy: 0.9671 - iou: 0.1359 - dice_coef: 0.2364 - precision: 0.0000e+00 - f1_score: 0.0000e+00 - val_loss: 0.1129 - val_accuracy: 0.9678 - val_iou: 0.0779 - val_dice_coef: 0.1385 - val_precision: 0.0000e+00 - val_f1_score: 0.0000e+00 - lr: 2.5000e-04
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1021 - accuracy: 0.9717 - iou: 0.1416 - dice_coef: 0.2452 - precision: 0.4535 - f1_score: 0.1247
# Epoch 11: val_loss did not improve from 0.10678
# 140/140 [==============================] - 91s 653ms/step - loss: 0.1021 - accuracy: 0.9717 - iou: 0.1416 - dice_coef: 0.2452 - precision: 0.4535 - f1_score: 0.1247 - val_loss: 0.1266 - val_accuracy: 0.9830 - val_iou: 0.0459 - val_dice_coef: 0.0818 - val_precision: 0.3395 - val_f1_score: 0.0983 - lr: 1.2500e-04
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1021 - accuracy: 0.9746 - iou: 0.1446 - dice_coef: 0.2496 - precision: 0.8917 - f1_score: 0.3045
# Epoch 12: val_loss did not improve from 0.10678
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1021 - accuracy: 0.9746 - iou: 0.1446 - dice_coef: 0.2496 - precision: 0.8917 - f1_score: 0.3045 - val_loss: 0.1171 - val_accuracy: 0.9773 - val_iou: 0.0678 - val_dice_coef: 0.1200 - val_precision: 0.4234 - val_f1_score: 0.1517 - lr: 1.2500e-04
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9758 - iou: 0.1480 - dice_coef: 0.2548 - precision: 0.8823 - f1_score: 0.3448
# Epoch 13: val_loss did not improve from 0.10678
# 140/140 [==============================] - 100s 719ms/step - loss: 0.1019 - accuracy: 0.9758 - iou: 0.1480 - dice_coef: 0.2548 - precision: 0.8823 - f1_score: 0.3448 - val_loss: 0.1120 - val_accuracy: 0.9660 - val_iou: 0.0711 - val_dice_coef: 0.1260 - val_precision: 0.4089 - val_f1_score: 0.1538 - lr: 6.2500e-05
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9757 - iou: 0.1498 - dice_coef: 0.2574 - precision: 0.8710 - f1_score: 0.3583
# Epoch 14: val_loss did not improve from 0.10678
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1018 - accuracy: 0.9757 - iou: 0.1498 - dice_coef: 0.2574 - precision: 0.8710 - f1_score: 0.3583 - val_loss: 0.1077 - val_accuracy: 0.9430 - val_iou: 0.0909 - val_dice_coef: 0.1610 - val_precision: 0.4760 - val_f1_score: 0.2046 - lr: 6.2500e-05
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9765 - iou: 0.1519 - dice_coef: 0.2605 - precision: 0.8686 - f1_score: 0.3676
# Epoch 15: val_loss did not improve from 0.10678
# 140/140 [==============================] - 101s 719ms/step - loss: 0.1018 - accuracy: 0.9765 - iou: 0.1519 - dice_coef: 0.2605 - precision: 0.8686 - f1_score: 0.3676 - val_loss: 0.1082 - val_accuracy: 0.9498 - val_iou: 0.0880 - val_dice_coef: 0.1556 - val_precision: 0.4821 - val_f1_score: 0.1926 - lr: 3.1250e-05
# Epoch 16/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9763 - iou: 0.1528 - dice_coef: 0.2620 - precision: 0.8670 - f1_score: 0.3722
# Epoch 16: val_loss did not improve from 0.10678
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 140/140 [==============================] - 101s 719ms/step - loss: 0.1017 - accuracy: 0.9763 - iou: 0.1528 - dice_coef: 0.2620 - precision: 0.8670 - f1_score: 0.3722 - val_loss: 0.1081 - val_accuracy: 0.9499 - val_iou: 0.0888 - val_dice_coef: 0.1570 - val_precision: 0.4797 - val_f1_score: 0.1954 - lr: 3.1250e-05
# Epoch 17/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9773 - iou: 0.1539 - dice_coef: 0.2635 - precision: 0.8654 - f1_score: 0.3754
# Epoch 17: val_loss did not improve from 0.10678
# 140/140 [==============================] - 101s 720ms/step - loss: 0.1017 - accuracy: 0.9773 - iou: 0.1539 - dice_coef: 0.2635 - precision: 0.8654 - f1_score: 0.3754 - val_loss: 0.1089 - val_accuracy: 0.9548 - val_iou: 0.0837 - val_dice_coef: 0.1478 - val_precision: 0.4658 - val_f1_score: 0.1818 - lr: 1.5625e-05
# Epoch 18/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9776 - iou: 0.1543 - dice_coef: 0.2641 - precision: 0.8649 - f1_score: 0.3767
# Epoch 18: val_loss did not improve from 0.10678
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 140/140 [==============================] - 101s 719ms/step - loss: 0.1016 - accuracy: 0.9776 - iou: 0.1543 - dice_coef: 0.2641 - precision: 0.8649 - f1_score: 0.3767 - val_loss: 0.1089 - val_accuracy: 0.9552 - val_iou: 0.0835 - val_dice_coef: 0.1474 - val_precision: 0.4467 - val_f1_score: 0.1816 - lr: 1.5625e-05
# Epoch 19/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9778 - iou: 0.1549 - dice_coef: 0.2650 - precision: 0.8642 - f1_score: 0.3788
# Epoch 19: val_loss did not improve from 0.10678
# 140/140 [==============================] - 101s 720ms/step - loss: 0.1016 - accuracy: 0.9778 - iou: 0.1549 - dice_coef: 0.2650 - precision: 0.8642 - f1_score: 0.3788 - val_loss: 0.1095 - val_accuracy: 0.9580 - val_iou: 0.0807 - val_dice_coef: 0.1424 - val_precision: 0.4212 - val_f1_score: 0.1751 - lr: 7.8125e-06
# Epoch 20/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9780 - iou: 0.1551 - dice_coef: 0.2653 - precision: 0.8640 - f1_score: 0.3792
# Epoch 20: val_loss did not improve from 0.10678
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 140/140 [==============================] - 101s 719ms/step - loss: 0.1016 - accuracy: 0.9780 - iou: 0.1551 - dice_coef: 0.2653 - precision: 0.8640 - f1_score: 0.3792 - val_loss: 0.1095 - val_accuracy: 0.9582 - val_iou: 0.0809 - val_dice_coef: 0.1427 - val_precision: 0.4213 - val_f1_score: 0.1757 - lr: 7.8125e-06
# Epoch 21/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9781 - iou: 0.1555 - dice_coef: 0.2659 - precision: 0.8629 - f1_score: 0.3810
# Epoch 21: val_loss did not improve from 0.10678
# 140/140 [==============================] - 101s 720ms/step - loss: 0.1016 - accuracy: 0.9781 - iou: 0.1555 - dice_coef: 0.2659 - precision: 0.8629 - f1_score: 0.3810 - val_loss: 0.1095 - val_accuracy: 0.9586 - val_iou: 0.0805 - val_dice_coef: 0.1419 - val_precision: 0.4212 - val_f1_score: 0.1749 - lr: 3.9063e-06
# Epoch 22/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9782 - iou: 0.1556 - dice_coef: 0.2660 - precision: 0.8632 - f1_score: 0.3809
# Epoch 22: val_loss did not improve from 0.10678
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 140/140 [==============================] - 92s 654ms/step - loss: 0.1016 - accuracy: 0.9782 - iou: 0.1556 - dice_coef: 0.2660 - precision: 0.8632 - f1_score: 0.3809 - val_loss: 0.1095 - val_accuracy: 0.9586 - val_iou: 0.0806 - val_dice_coef: 0.1421 - val_precision: 0.4204 - val_f1_score: 0.1753 - lr: 3.9063e-06
# Epoch 23/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9783 - iou: 0.1558 - dice_coef: 0.2663 - precision: 0.8628 - f1_score: 0.3819
# Epoch 23: val_loss did not improve from 0.10678
# 140/140 [==============================] - 91s 653ms/step - loss: 0.1016 - accuracy: 0.9783 - iou: 0.1558 - dice_coef: 0.2663 - precision: 0.8628 - f1_score: 0.3819 - val_loss: 0.1095 - val_accuracy: 0.9586 - val_iou: 0.0807 - val_dice_coef: 0.1423 - val_precision: 0.4201 - val_f1_score: 0.1754 - lr: 1.9531e-06
# Epoch 24/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9783 - iou: 0.1558 - dice_coef: 0.2664 - precision: 0.8630 - f1_score: 0.3817
# Epoch 24: val_loss did not improve from 0.10678
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 140/140 [==============================] - 91s 653ms/step - loss: 0.1016 - accuracy: 0.9783 - iou: 0.1558 - dice_coef: 0.2664 - precision: 0.8630 - f1_score: 0.3817 - val_loss: 0.1095 - val_accuracy: 0.9586 - val_iou: 0.0808 - val_dice_coef: 0.1423 - val_precision: 0.4198 - val_f1_score: 0.1755 - lr: 1.9531e-06
# Epoch 25/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1560 - dice_coef: 0.2665 - precision: 0.8628 - f1_score: 0.3822
# Epoch 25: val_loss did not improve from 0.10678
# 140/140 [==============================] - 91s 653ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1560 - dice_coef: 0.2665 - precision: 0.8628 - f1_score: 0.3822 - val_loss: 0.1095 - val_accuracy: 0.9585 - val_iou: 0.0808 - val_dice_coef: 0.1425 - val_precision: 0.4205 - val_f1_score: 0.1757 - lr: 9.7656e-07
# Epoch 26/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1560 - dice_coef: 0.2666 - precision: 0.8630 - f1_score: 0.3821
# Epoch 26: val_loss did not improve from 0.10678
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 140/140 [==============================] - 91s 652ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1560 - dice_coef: 0.2666 - precision: 0.8630 - f1_score: 0.3821 - val_loss: 0.1095 - val_accuracy: 0.9585 - val_iou: 0.0808 - val_dice_coef: 0.1425 - val_precision: 0.4203 - val_f1_score: 0.1757 - lr: 9.7656e-07
# Epoch 27/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1560 - dice_coef: 0.2666 - precision: 0.8628 - f1_score: 0.3823
# Epoch 27: val_loss did not improve from 0.10678
# 140/140 [==============================] - 91s 653ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1560 - dice_coef: 0.2666 - precision: 0.8628 - f1_score: 0.3823 - val_loss: 0.1095 - val_accuracy: 0.9585 - val_iou: 0.0809 - val_dice_coef: 0.1426 - val_precision: 0.4201 - val_f1_score: 0.1759 - lr: 4.8828e-07
# Epoch 28/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1560 - dice_coef: 0.2666 - precision: 0.8629 - f1_score: 0.3823
# Epoch 28: val_loss did not improve from 0.10678
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1560 - dice_coef: 0.2666 - precision: 0.8629 - f1_score: 0.3823 - val_loss: 0.1095 - val_accuracy: 0.9585 - val_iou: 0.0809 - val_dice_coef: 0.1426 - val_precision: 0.4199 - val_f1_score: 0.1759 - lr: 4.8828e-07
# Epoch 29/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8628 - f1_score: 0.3824
# Epoch 29: val_loss did not improve from 0.10678
# 140/140 [==============================] - 92s 654ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8628 - f1_score: 0.3824 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0809 - val_dice_coef: 0.1427 - val_precision: 0.4199 - val_f1_score: 0.1759 - lr: 2.4414e-07
# Epoch 30/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3824
# Epoch 30: val_loss did not improve from 0.10678
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3824 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0809 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1759 - lr: 2.4414e-07
# Epoch 31/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825
# Epoch 31: val_loss did not improve from 0.10678
# 140/140 [==============================] - 92s 654ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.2207e-07
# Epoch 32/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825
# Epoch 32: val_loss did not improve from 0.10678
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-07.
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.2207e-07
# Epoch 33/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825
# Epoch 33: val_loss did not improve from 0.10678
# 140/140 [==============================] - 91s 653ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 34/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825
# Epoch 34: val_loss did not improve from 0.10678
# 140/140 [==============================] - 91s 653ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 35/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825
# Epoch 35: val_loss did not improve from 0.10678
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 36/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8628 - f1_score: 0.3825
# Epoch 36: val_loss did not improve from 0.10678
# 140/140 [==============================] - 92s 654ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8628 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 37/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8628 - f1_score: 0.3825
# Epoch 37: val_loss did not improve from 0.10678
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8628 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 38/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825
# Epoch 38: val_loss did not improve from 0.10678
# 140/140 [==============================] - 101s 719ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 39/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825
# Epoch 39: val_loss did not improve from 0.10678
# 140/140 [==============================] - 91s 653ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 40/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825
# Epoch 40: val_loss did not improve from 0.10678
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 41/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825
# Epoch 41: val_loss did not improve from 0.10678
# 140/140 [==============================] - 101s 719ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2667 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 42/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825
# Epoch 42: val_loss did not improve from 0.10678
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 43/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825
# Epoch 43: val_loss did not improve from 0.10678
# 140/140 [==============================] - 101s 719ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 44/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825
# Epoch 44: val_loss did not improve from 0.10678
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 45/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825
# Epoch 45: val_loss did not improve from 0.10678
# 140/140 [==============================] - 91s 654ms/step - loss: 0.1016 - accuracy: 0.9784 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 46/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9785 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825
# Epoch 46: val_loss did not improve from 0.10678
# 140/140 [==============================] - 91s 652ms/step - loss: 0.1016 - accuracy: 0.9785 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 47/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9785 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825
# Epoch 47: val_loss did not improve from 0.10678
# 140/140 [==============================] - 100s 719ms/step - loss: 0.1016 - accuracy: 0.9785 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 48/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9785 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825
# Epoch 48: val_loss did not improve from 0.10678
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1016 - accuracy: 0.9785 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 49/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9785 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825
# Epoch 49: val_loss did not improve from 0.10678
# 140/140 [==============================] - 91s 654ms/step - loss: 0.1016 - accuracy: 0.9785 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07
# Epoch 50/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9785 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825
# Epoch 50: val_loss did not improve from 0.10678
# 140/140 [==============================] - 100s 718ms/step - loss: 0.1016 - accuracy: 0.9785 - iou: 0.1561 - dice_coef: 0.2668 - precision: 0.8629 - f1_score: 0.3825 - val_loss: 0.1094 - val_accuracy: 0.9585 - val_iou: 0.0810 - val_dice_coef: 0.1427 - val_precision: 0.4198 - val_f1_score: 0.1760 - lr: 1.0000e-07

# %%
history = model.history.history

def plot_metrics(history):
    
    train_loss = history['loss']
    val_loss = history['val_loss']
    train_acc = history['accuracy']
    val_acc = history['val_accuracy']
    
    # Loss
    plt.figure()
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    plt.show()
    
    # Accuracy
    plt.figure()
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    plt.show()
plot_metrics(history)

# %% [markdown]
# # Testing

# %%
model.save('/content/drive/MyDrive/glucomadata/weights.h5')

# %%
plt.plot(loss, label='Training loss')
plt.plot(val_loss, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-3bf8fbcdae5a> in <cell line: 1>()
# ----> 1 plt.plot(loss, label='Training loss')
#       2 plt.plot(val_loss, label='Validation loss')
#       3 plt.xlabel('Epoch')
#       4 plt.ylabel('Loss')
#       5 plt.title('Training and Validation Loss')
#
# NameError: name 'loss' is not defined

# %%
img = np.array((x_test[20]))
# img = cv2.resize(img, (512,512),interpolation = cv2.INTER_AREA)
img.shape
np.unique(img)
img1 = np.expand_dims(img,axis =0)
img1.shape

prediction = model.predict(img1)
prediction.shape
plt.imshow(prediction[0][:,:,0]>0.5, cmap='gray')
plt.show()
plt.imshow(prediction[0][:,:,1]>0.5, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 1s 756ms/step

# %%
img = np.array((x_test[13]))
# img = cv2.resize(img, (512,512),interpolation = cv2.INTER_AREA)
img.shape
np.unique(img)
img1 = np.expand_dims(img,axis =0)
img1.shape

prediction = model.predict(img1)
prediction.shape
plt.imshow(prediction[0][:,:,0]>0.5, cmap='gray')
plt.show()
plt.imshow(prediction[0][:,:,1]>0.5, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
#model = load_model('/content/drive/MyDrive/glucomadata/weights.h5')

# %%
img = np.array((x_test[8]))
# img = cv2.resize(img, (512,512),interpolation = cv2.INTER_AREA)
img.shape
np.unique(img)
img1 = np.expand_dims(img,axis =0)
img1.shape

prediction = model.predict(img1)
prediction.shape
plt.imshow(prediction[0][:,:,0]>0.5, cmap='gray')
plt.show()
plt.imshow(prediction[0][:,:,1]>0.5, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step

# %%
img = np.array((x_test[15]))
# img = cv2.resize(img, (512,512),interpolation = cv2.INTER_AREA)
img.shape
np.unique(img)
img1 = np.expand_dims(img,axis =0)
img1.shape

prediction = model.predict(img1)
prediction.shape
plt.imshow(prediction[0][:,:,0]>0.5, cmap='gray')
plt.show()
plt.imshow(prediction[0][:,:,1]>0.5, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
